# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy import stats as scp
from collections import Counter
from sklearn.cluster import KMeans

# %%
def toBinary(threshold, element):
    return 1 if element > threshold else 0

npToBinary = np.vectorize(toBinary, otypes=[np.uint8])

# %%
def filterNoiseAndBG(size):
    return size > 50 and size < 10000

# %%
def classify(clustersNumber, centroidMean, counter):
    
    pecas = dict()
    
    if clustersNumber == 1:    
        if centroidMean > 1000:
            pecas["porcas"] = 0
            pecas["parafusos"] = counter.get(0)
            return pecas
        
        pecas["porcas"] = counter.get(0)
        pecas["parafusos"] = 0
        return pecas
    pecas["porcas"] = counter.get(0)
    pecas["parafusos"] = counter.get(1)
    return pecas

# %%
pathList = list()
for path, subdirs, files in os.walk(r"/home/martin/Downloads/uninove/"):
    for file in files:
        if 'jpg' in file:
            currentFilePath = "".join(path) + file
            pathList.append(currentFilePath)
pathList = sorted(pathList)

# %%
def analyzeImage(limiarBase, caminhoImagem):

    LIMIAR = limiarBase
    contador = None
    pecas = dict()
    CLUSTERS = 2

    testImage = cv.imread(caminhoImagem, cv.IMREAD_GRAYSCALE)

    while True:

        binaryImage = npToBinary(LIMIAR, testImage)

        nlabels, labels, stats, centroids = cv.connectedComponentsWithStats(binaryImage, 8, cv.CV_32S)

        # só estamos interessados na coluna de aŕea total do componente conexo
        areaSlice = stats[:, cv.CC_STAT_AREA]

        # realizamos o sort para que se possa remover valores incorretos, 
        # como áreas muito pequenas ou o background
        areaArray = np.sort(np.asarray(list(filter(filterNoiseAndBG, areaSlice))))
        areaArray = areaArray.reshape(areaArray.size, 1)
    
        if areaArray.std() < 100:
            CLUSTERS = 1

        # se tivermos um desvio padrão elevado, significa que estamos
        # lidando tanto com porcas quanto parafusos
        initializationArray = None
        if areaArray.std() < 100:
            initializationArray = np.array([[500]])
            CLUSTERS = 1
        else:
            initializationArray = np.array([[400], [1500]])

        kmeans = KMeans(n_clusters=CLUSTERS, max_iter=50, n_init=1,init=initializationArray).fit(areaArray)
        contador = Counter(kmeans.labels_)

        # caso não exista marcamos como 0
        pecas = classify(centroidMean=kmeans.cluster_centers_, clustersNumber=CLUSTERS, counter=contador)

        if LIMIAR > 250:
            raise Exception("LIMIAR maior que 250")
            break

        if pecas["porcas"] > 10 or pecas["parafusos"] > 10:
            LIMIAR += 5
        elif pecas["porcas"] < 11 or pecas["parafusos"] < 11:
            return (pecas, LIMIAR)

# %%
parafusos = [10,10,10,5,9,10,7,7,10,10,10,10,10,10,9,0,7,10,7,10,10,10,8,9,10]
porcas = [10,10,10,10,9,10,10,10,10,9,0,10,9,10,10,10,7,10,9,10,10,10,8,10,9]

acertosParafusos = 0
acertosPorcas = 0
acertos = 0

for index, imagePath in enumerate(pathList):
    
    if index == 12:
        continue
        
    baseLimiar = 150
    pecas, LIMIAR = analyzeImage(baseLimiar, imagePath)
    
    contPorcas = pecas["porcas"]
    contParafusos = pecas["parafusos"]
    
    if (porcas[index] == contPorcas):
        acertosPorcas += 1
    if (parafusos[index] == contParafusos):
        acertosParafusos += 1
    if (porcas[index] == contPorcas and parafusos[index] == contParafusos):
        acertos += 1
    
    print("INFO; Imagem No", index)
    print("Imagem: ", imagePath)
    print("Limiar: {}. No Porcas: {}, No Parafusos: {}".format(LIMIAR, contPorcas, contParafusos))
    print("Número correto de porcas: {}, parafusos: {}".format(porcas[index], parafusos[index]))
    print("\nTaxa de acertos (Parafusos):", round((acertosParafusos/len(porcas)*100),2))
    print("Taxa de acertos (Porcas): ", round((acertosPorcas/len(porcas)*100),2))
    print("Taxa de acertos:", round((acertos/25*100),2))
    print("----------")
# Out:
# INFO; Imagem No 0
# Imagem:  /home/martin/Downloads/uninove/img01.jpg
# Limiar: 150. No Porcas: 10, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 10
#
# Taxa de acertos (Parafusos): 4.0
# Taxa de acertos (Porcas):  4.0
# Taxa de acertos: 4.0
# ----------
# INFO; Imagem No 1
# Imagem:  /home/martin/Downloads/uninove/img02.jpg
# Limiar: 155. No Porcas: 10, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 10
#
# Taxa de acertos (Parafusos): 8.0
# Taxa de acertos (Porcas):  8.0
# Taxa de acertos: 8.0
# ----------
# INFO; Imagem No 2
# Imagem:  /home/martin/Downloads/uninove/img03.jpg
# Limiar: 150. No Porcas: 10, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 10
#
# Taxa de acertos (Parafusos): 12.0
# Taxa de acertos (Porcas):  12.0
# Taxa de acertos: 12.0
# ----------
# INFO; Imagem No 3
# Imagem:  /home/martin/Downloads/uninove/img04.jpg
# Limiar: 170. No Porcas: 10, No Parafusos: 5
# Número correto de porcas: 10, parafusos: 5
#
# Taxa de acertos (Parafusos): 16.0
# Taxa de acertos (Porcas):  16.0
# Taxa de acertos: 16.0
# ----------
# INFO; Imagem No 4
# Imagem:  /home/martin/Downloads/uninove/img05.jpg
# Limiar: 185. No Porcas: 9, No Parafusos: 9
# Número correto de porcas: 9, parafusos: 9
#
# Taxa de acertos (Parafusos): 20.0
# Taxa de acertos (Porcas):  20.0
# Taxa de acertos: 20.0
# ----------
# INFO; Imagem No 5
# Imagem:  /home/martin/Downloads/uninove/img06.jpg
# Limiar: 150. No Porcas: 10, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 10
#
# Taxa de acertos (Parafusos): 24.0
# Taxa de acertos (Porcas):  24.0
# Taxa de acertos: 24.0
# ----------
# INFO; Imagem No 6
# Imagem:  /home/martin/Downloads/uninove/img07.jpg
# Limiar: 170. No Porcas: 10, No Parafusos: 7
# Número correto de porcas: 10, parafusos: 7
#
# Taxa de acertos (Parafusos): 28.0
# Taxa de acertos (Porcas):  28.0
# Taxa de acertos: 28.0
# ----------
# INFO; Imagem No 7
# Imagem:  /home/martin/Downloads/uninove/img08.jpg
# Limiar: 185. No Porcas: 10, No Parafusos: 7
# Número correto de porcas: 10, parafusos: 7
#
# Taxa de acertos (Parafusos): 32.0
# Taxa de acertos (Porcas):  32.0
# Taxa de acertos: 32.0
# ----------
# INFO; Imagem No 8
# Imagem:  /home/martin/Downloads/uninove/img09.jpg
# Limiar: 150. No Porcas: 10, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 10
#
# Taxa de acertos (Parafusos): 36.0
# Taxa de acertos (Porcas):  36.0
# Taxa de acertos: 36.0
# ----------
# INFO; Imagem No 9
# Imagem:  /home/martin/Downloads/uninove/img10.jpg
# Limiar: 160. No Porcas: 9, No Parafusos: 10
# Número correto de porcas: 9, parafusos: 10
#
# Taxa de acertos (Parafusos): 40.0
# Taxa de acertos (Porcas):  40.0
# Taxa de acertos: 40.0
# ----------
# INFO; Imagem No 10
# Imagem:  /home/martin/Downloads/uninove/img11.jpg
# Limiar: 170. No Porcas: 0, No Parafusos: 10
# Número correto de porcas: 0, parafusos: 10
#
# Taxa de acertos (Parafusos): 44.0
# Taxa de acertos (Porcas):  44.0
# Taxa de acertos: 44.0
# ----------
# INFO; Imagem No 11
# Imagem:  /home/martin/Downloads/uninove/img12.jpg
# Limiar: 150. No Porcas: 10, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 10
#
# Taxa de acertos (Parafusos): 48.0
# Taxa de acertos (Porcas):  48.0
# Taxa de acertos: 48.0
# ----------
# INFO; Imagem No 13
# Imagem:  /home/martin/Downloads/uninove/img14.jpg
# Limiar: 150. No Porcas: 10, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 10
#
# Taxa de acertos (Parafusos): 52.0
# Taxa de acertos (Porcas):  52.0
# Taxa de acertos: 52.0
# ----------
# INFO; Imagem No 14
# Imagem:  /home/martin/Downloads/uninove/img15.jpg
# Limiar: 170. No Porcas: 10, No Parafusos: 9
# Número correto de porcas: 10, parafusos: 9
#
# Taxa de acertos (Parafusos): 56.0
# Taxa de acertos (Porcas):  56.0
# Taxa de acertos: 56.0
# ----------
# INFO; Imagem No 15
# Imagem:  /home/martin/Downloads/uninove/img16.jpg
# Limiar: 175. No Porcas: 2, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 0
#
# Taxa de acertos (Parafusos): 56.0
# Taxa de acertos (Porcas):  56.0
# Taxa de acertos: 56.0
# ----------
# INFO; Imagem No 16
# Imagem:  /home/martin/Downloads/uninove/img17.jpg
# Limiar: 175. No Porcas: 7, No Parafusos: 7
# Número correto de porcas: 7, parafusos: 7
#
# Taxa de acertos (Parafusos): 60.0
# Taxa de acertos (Porcas):  60.0
# Taxa de acertos: 60.0
# ----------
# INFO; Imagem No 17
# Imagem:  /home/martin/Downloads/uninove/img18.jpg
# Limiar: 170. No Porcas: 10, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 10
#
# Taxa de acertos (Parafusos): 64.0
# Taxa de acertos (Porcas):  64.0
# Taxa de acertos: 64.0
# ----------
# INFO; Imagem No 18
# Imagem:  /home/martin/Downloads/uninove/img19.jpg
# Limiar: 175. No Porcas: 9, No Parafusos: 7
# Número correto de porcas: 9, parafusos: 7
#
# Taxa de acertos (Parafusos): 68.0
# Taxa de acertos (Porcas):  68.0
# Taxa de acertos: 68.0
# ----------
# INFO; Imagem No 19
# Imagem:  /home/martin/Downloads/uninove/img20.jpg
# Limiar: 150. No Porcas: 10, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 10
#
# Taxa de acertos (Parafusos): 72.0
# Taxa de acertos (Porcas):  72.0
# Taxa de acertos: 72.0
# ----------
# INFO; Imagem No 20
# Imagem:  /home/martin/Downloads/uninove/img21.jpg
# Limiar: 180. No Porcas: 10, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 10
#
# Taxa de acertos (Parafusos): 76.0
# Taxa de acertos (Porcas):  76.0
# Taxa de acertos: 76.0
# ----------
# INFO; Imagem No 21
# Imagem:  /home/martin/Downloads/uninove/img22.jpg
# Limiar: 170. No Porcas: 10, No Parafusos: 10
# Número correto de porcas: 10, parafusos: 10
#
# Taxa de acertos (Parafusos): 80.0
# Taxa de acertos (Porcas):  80.0
# Taxa de acertos: 80.0
# ----------
# INFO; Imagem No 22
# Imagem:  /home/martin/Downloads/uninove/img23.jpg
# Limiar: 165. No Porcas: 8, No Parafusos: 8
# Número correto de porcas: 8, parafusos: 8
#
# Taxa de acertos (Parafusos): 84.0
# Taxa de acertos (Porcas):  84.0
# Taxa de acertos: 84.0
# ----------
# INFO; Imagem No 23
# Imagem:  /home/martin/Downloads/uninove/img24.jpg
# Limiar: 170. No Porcas: 10, No Parafusos: 9
# Número correto de porcas: 10, parafusos: 9
#
# Taxa de acertos (Parafusos): 88.0
# Taxa de acertos (Porcas):  88.0
# Taxa de acertos: 88.0
# ----------
# INFO; Imagem No 24
# Imagem:  /home/martin/Downloads/uninove/img25.jpg
# Limiar: 165. No Porcas: 9, No Parafusos: 10
# Número correto de porcas: 9, parafusos: 10
#
# Taxa de acertos (Parafusos): 92.0
# Taxa de acertos (Porcas):  92.0
# Taxa de acertos: 92.0
# ----------
